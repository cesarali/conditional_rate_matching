# %%
from torch.utils.data import DataLoader
from utils import plot_images
from datasets import load_nist_data

cmap = 'inferno'
device = 'cuda:0'

# %%
dataname = 'MNIST'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap=cmap)

#...train classifier

from utils import train_classifier
from architectures import LeNet5

model = LeNet5(num_classes=10) 
train_classifier(model, 
                 train_dataloader, 
                 test_dataloader,
                 device=device,
                 accuracy_goal=98.5,
                 save_as='models/LeNet5_{}.pth'.format('_'.join(dataname.split(' '))), 
                 epochs=100, 
                 lr=0.001)
# Out:
# Epochs:   1%|          | 1/99 [00:19<31:12, 19.10s/it]
# accuracy goal reached. Stopping training at 98.5 epochs
# final accuracy: 98.54%

# %%
dataname = 'MNIST'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=256, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=256, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap=cmap)

#...train classifier

from utils import train_classifier
from architectures import ResNet18

model = ResNet18(num_classes=10) 
train_classifier(model, 
                 train_dataloader, 
                 test_dataloader,
                 device=device,
                 accuracy_goal=99.5,
                 save_as='models/ResNet18_{}.pth'.format('_'.join(dataname.split(' '))), 
                 epochs=100, 
                 lr=0.001)

# %%
dataname = 'BinaryMNIST'
test_dataset = load_nist_data(name=dataname, train=False)
test_dataloader = DataLoader(test_dataset, batch_size=256, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap=cmap)


#...train classifier

from utils import train_classifier
from architectures import LeNet5

model = LeNet5(num_classes=10) 
train_classifier(model, 
                 train_dataloader, 
                 test_dataloader,
                 accuracy_goal=98.5,
                 save_as='models/LeNet5_{}.pth'.format('_'.join(dataname.split(' '))), 
                 epochs=100, 
                 lr=0.001)

# %%
dataname = 'EMNIST Letters'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap=cmap)

#...train classifier

# TODO
# Out:
# ...
# 100%|██████████| 561753746/561753746 [00:08<00:00, 66468255.33it/s]
# Extracting ./data/EMNIST/raw/gzip.zip to ./data/EMNIST/raw

# %%
dataname = 'BinaryEMNIST Letters'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap='gray')

#...train classifier

#...train classifier

from utils import train_classifier
from architectures import ResNet18

model = ResNet18(num_classes=10) 
train_classifier(model, 
                 train_dataloader, 
                 test_dataloader,
                 device=device,
                 accuracy_goal=90,
                 save_as='models/ResNet18_{}.pth'.format('_'.join(dataname.split(' '))), 
                 epochs=100, 
                 lr=0.001)

# %%
dataname = 'EMNIST Byclass'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap=cmap)

#...train classifier

# TODO

# %%
dataname = 'BinaryEMNIST Byclass'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap='gray')

#...train classifier

# TODO

# %%
dataname = 'Omniglot'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap=cmap+ '_r')

#...train classifier

# TODO
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dataname = 'BinaryOmniglot'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap='gray_r')

#...train classifier

# TODO
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dataname = 'FashionMNIST'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap=cmap)

#...train classifier

from utils import train_classifier
from architectures import ResNet18

model = ResNet18(num_classes=10) 
train_classifier(model, 
                 train_dataloader, 
                 test_dataloader,
                 device=device,
                 accuracy_goal=90,
                 save_as='models/ResNet18_{}.pth'.format('_'.join(dataname.split(' '))), 
                 epochs=100, 
                 lr=0.001)
# Out:
# ...
# 100%|██████████| 26421880/26421880 [00:03<00:00, 8184536.37it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 29515/29515 [00:00<00:00, 337145.81it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 4422102/4422102 [00:00<00:00, 5441769.50it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 5148/5148 [00:00<00:00, 9223527.12it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
# Epochs:   3%|▎         | 3/99 [02:05<1:06:05, 41.31s/it]
# current accuracy: 89.34%
# Epochs:   3%|▎         | 3/99 [02:46<1:28:52, 55.55s/it]
# accuracy goal reached. Stopping training at 90 epochs
# final accuracy: 91.07%

# %%
dataname = 'BinaryFashionMNIST'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(test_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap='gray')

#...train classifier

# TODO

# %%
dataname = 'CIFAR10'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(train_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5))

#...train classifier

# TODO
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dataname = 'BinaryCIFAR10'
train_dataset = load_nist_data(name=dataname)
test_dataset = load_nist_data(name=dataname, train=False)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)
images, _ = next(iter(train_dataloader))

plot_images(images, dataname, figsize=(3.5, 3.5), cmap='gray')

#...train classifier

# TODO
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
